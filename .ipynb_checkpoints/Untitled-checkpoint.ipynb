# %%
import torch
import matplotlib.pyplot as plt
import pandas
import numpy as np

# %%
# set up input data
batchSize = 10;

# %%
# set up RNN
model = torch.nn.LSTM()

# %%
rnn = torch.nn.LSTM(10, 20, 3)
input = torch.randn(5, 1, 10)
output, (hn, cn) = rnn(input)

# %%
x = input.detach().numpy();
y = output.detach().numpy();

# %%
plt.plot(input.view(5,-1,1).detach().numpy().flatten())
plt.plot(output.view(5,-1,1).detach().numpy().flatten())
